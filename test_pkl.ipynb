# %%
import pickle

# %%
sample_data = pickle.load(open("./processed_data/vietnamese_bert_features.pkl", "rb"))

# %%
sample_data
# Out:
# {'features': array([[ 0.01704724,  0.18624155,  0.17065172, ..., -0.16255869,
#           0.00232763,  0.03865861],
#         [ 0.21698962,  0.35557565,  0.1051326 , ..., -0.30861267,
#           0.02138064,  0.08586147],
#         [ 0.04496029, -0.00191745,  0.08243978, ..., -0.22875848,
#          -0.18261251,  0.02258138],
#         [ 0.26876777,  0.3152137 , -0.10054161, ..., -0.23912877,
#           0.0858423 ,  0.00094839]], shape=(4, 768), dtype=float32),
#  'labels': array([0, 1, 0, 1]),
#  'language': 'vietnamese',
#  'model_name': 'vinai/phobert-base'}
