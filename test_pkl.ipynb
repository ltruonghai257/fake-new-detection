# %%
import pickle

# %%
sample_data = pickle.load(
    open("./processed_data/vietnamese_multimodal_test/test/combined_dataset.pkl", "rb")
)

# %%
sample_data["image_features"][0].shape
# Out:
# (512,)
