# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Load Preprocess dataa

# %% [markdown]
# ### Imports

# %%
import numpy as np
import os

# %%
def load_preprocessed_data(data_dir="./processed_data/crawled", combined=True):
    """Load preprocessed data from NPZ files.

    Args:
        data_dir: Directory containing preprocessed files
        combined: If True, load combined_dataset.npz; else load separate text/image files

    Returns:
        If combined: (text_features, image_features, labels)
        Else: (text_features, labels), (image_features, labels)
    """

    data_dir = os.path.expanduser(data_dir)

    if combined:
        # Load combined dataset
        combined_path = os.path.join(data_dir, "combined_dataset.npz")
        data = np.load(combined_path)
        return data["text_features"], data["image_features"], data["labels"]
    else:
        # Load separate files
        text_data = np.load(os.path.join(data_dir, "text_features.npz"))
        image_data = np.load(os.path.join(data_dir, "image_features.npz"))
        return (text_data["features"], text_data["labels"]), (
            image_data["features"],
            image_data["labels"],
        )

# %%
loaded_data = load_preprocessed_data(data_dir="/content/drive/MyDrive/Thesis_Final/fake-new-detection/notebooks/processed_data/crawled")

# %% [markdown]
# After running the cell above and authenticating, your Google Drive will be mounted. You can then replace `"path/to/your/data"` with the actual path to your `processed_data/crawled` directory on your Google Drive. For example, if your `processed_data` folder is directly in 'MyDrive', the path would be `"/content/drive/MyDrive/processed_data/crawled"`.

# %%
loaded_data[1].shape
# Out:
# (4814, 2048)

# %%
loaded_data[0]
# Out:
# array([[[-0.00905533,  0.6600026 , -0.6251642 , ...,  0.0781768 ,
#          -0.05546551, -0.19615144],
#         [-0.2657627 ,  0.51240957,  0.19044149, ..., -0.02083158,
#           0.24871005,  0.4988681 ],
#         [-0.27693754,  1.0698819 , -0.08966036, ...,  0.11263381,
#          -0.27296853, -0.26141274],
#         ...,
#         [-0.07882759,  0.72318995, -0.30205792, ...,  0.23735762,
#           0.13369921,  0.42166153],
#         [-0.42946696,  1.117198  , -0.35591227, ...,  0.42110804,
#          -0.20674947, -0.70483136],
#         [-0.04859641,  0.61225086, -0.6563626 , ...,  0.08429685,
#          -0.13849632, -0.29782215]],
#
#        [[-0.23887596,  0.9346718 , -0.501658  , ..., -0.01295989,
#           0.08901384,  0.38171908],
#         [-0.23456176,  0.21207727, -0.39937282, ..., -0.29292703,
#           0.05123863, -0.37416446],
#         [-0.50314915,  0.31460863, -0.69173217, ..., -0.34310746,
#           0.2208858 ,  0.03528984],
#         ...,
#         [-0.23824151,  0.7454467 , -0.22024544, ..., -0.21366075,
#          -0.12796444,  0.03938796],
#         [-0.30444637,  0.3173365 , -0.28805736, ..., -0.26059303,
#          -0.07333679,  0.4340174 ],
#         [-0.3157449 ,  0.8862656 , -0.47912842, ...,  0.04850961,
#           0.03146186,  0.3328236 ]],
#
#        [[-0.09885557,  0.47659206, -0.39755765, ...,  0.01331605,
#          -0.1183735 , -0.03693245],
#         [-0.50206757,  0.6431565 , -0.18729419, ...,  0.32414514,
#           0.4850107 ,  0.2921945 ],
#         [-0.34560668,  0.6970441 , -0.0459547 , ..., -0.1460231 ,
#          -0.06048157,  0.35246256],
#         ...,
#         [-0.22064374,  0.39278445, -0.4684194 , ..., -0.09223878,
#          -0.11932553,  0.42603007],
#         [-0.51813513,  0.9255926 , -0.4465328 , ...,  0.256176  ,
#          -0.5046238 , -0.39274055],
#         [-0.17363286,  0.45954674, -0.42569798, ...,  0.00266478,
#          -0.21556708, -0.10772812]],
#
#        ...,
#
#        [[-0.37901664,  0.70855755, -0.5527977 , ...,  0.09854122,
#          -0.41274387, -0.43920553],
#         [-0.0063797 , -0.19735098, -0.19329727, ..., -0.34465644,
#          -0.29652023, -0.10572435],
#         [-0.10836949, -0.17928603, -0.20153058, ..., -0.16196787,
#          -0.59272367, -0.28706887],
#         ...,
#         [-0.5730832 ,  0.52525795,  0.02374537, ..., -0.37648883,
#          -0.44130066, -0.03005964],
#         [-0.5730832 ,  0.52525795,  0.02374537, ..., -0.37648883,
#          -0.44130066, -0.03005964],
#         [-0.5730832 ,  0.52525795,  0.02374537, ..., -0.37648883,
#          -0.44130066, -0.03005964]],
#
#        [[-0.14164804,  0.6371489 , -0.5972866 , ...,  0.32731298,
#          -0.08564048,  0.2877919 ],
#         [-0.13606787,  0.99458665, -0.27781135, ...,  0.3098264 ,
#          -0.3862893 ,  0.35629717],
#         [-0.10469405,  0.5678878 , -0.10535847, ..., -0.06564866,
#          -0.6129724 , -0.05045046],
#         ...,
#         [-0.18997465,  0.7969841 , -0.58457875, ...,  0.50945306,
#          -0.3968737 ,  0.6305404 ],
#         [-0.18997465,  0.7969841 , -0.58457875, ...,  0.50945306,
#          -0.3968737 ,  0.6305404 ],
#         [-0.18997465,  0.7969841 , -0.58457875, ...,  0.50945306,
#          -0.3968737 ,  0.6305404 ]],
#
#        [[ 0.10794097,  0.77637744, -0.72583324, ...,  0.13006076,
#          -0.20769006, -0.07634231],
#         [-0.39576867,  0.4695284 , -0.20690033, ...,  0.49993768,
#          -0.14687014,  0.3138215 ],
#         [-0.4535847 ,  0.10052578,  0.3644667 , ...,  0.51171714,
#           0.5726472 ,  0.6581721 ],
#         ...,
#         [-0.14392391,  0.9499936 , -0.22233912, ...,  0.2207208 ,
#          -0.12816684, -0.09127885],
#         [-0.03929798,  0.70063597, -0.57142246, ...,  0.18089704,
#           0.14974064, -0.10995261],
#         [ 0.05873454,  0.7287101 , -0.72526157, ...,  0.19003388,
#          -0.32577813, -0.17003265]]], dtype=float32)
